# %% [markdown]
# Libraries Imported

# %%
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# URLs Requests

# %%
URLs = 'http://www.ftu.ac.th/2019/index.php/th/'
Re = requests.get(URLs)

# %%
Re.text
# Out:
# tem_img img-intro img-intro__none&quot;&gt; \n\t\t\t&lt;img src=&quot;http://www.ftu.ac.th/2019/images/team/dr-mazlan.jpg&quot; alt=&quot;&quot;&gt;\n\t\t&lt;/figure&gt;\n&lt;div class=&quot;item_content&quot;&gt;\n\t&lt;!-- Item title --&gt;\n\t\t&lt;h4 class=&quot;item_title item_title__center&quot;&gt;\n\t\t&lt;span class=&quot;item_title_part0 item_title_part_odd item_title_part_first_half item_title_part_first&quot;&gt;ผศ.ดร.มัซลัน&lt;/span&gt; &lt;span class=&quot;item_title_part1 item_title_part_even item_title_part_second_half item_title_part_last&quot;&gt;สุหลง&lt;/span&gt; \t&lt;/h4&gt;\n\t\t&lt;!-- Introtext --&gt;\n\t&lt;div class=&quot;item_introtext&quot;&gt;\n\t\t&lt;p&gt;รองอธิการบดีฝ่ายแผนและประกันคุณภาพการศึกษา&lt;/p&gt;\r\n&lt;p&gt;&lt;a href=&quot;/2019/index.php/contacts&quot;&gt;Contacts&lt;/a&gt;&lt;/p&gt;\t&lt;/div&gt;\n\t\n\t\n\t&lt;!-- Read More link --&gt;\n\t&lt;/div&gt;\n&lt;div class=&quot;clearfix&quot;&gt;&lt;/div&gt;  &lt;/article&gt;\n  &lt;/div&gt;&
# ...

# %% [markdown]
# BeautifulSoup

# %%
Soup = BeautifulSoup(Re.content, 'html.parser')

# %%
def print_hyperlinks():
    for links in Soup.find_all('a'):
        print(links)

# %%
print_hyperlinks()
# Out:
# &lt;/a&gt;
# &lt;a class=&quot;readon fleft&quot; href=&quot;/2019/index.php/th/ftunews-3/275-event621126&quot; target=&quot;_self&quot;&gt;Read more&lt;/a&gt;
# &lt;a href=&quot;/2019/index.php/th/ftunews-3/252-marathon2019&quot; target=&quot;_self&quot; title=&quot;เชิญเข้าร่วมกิจกรรม FTU MINI MARATHON FOR PEACE 2019&quot;&gt;&lt;span&gt;เชิญเข้าร่วมกิจกรรม&lt;/span&gt; FTU MINI MARATHON FOR PEACE 2019&lt;/a&gt;
# &lt;a class=&quot;nspImageWrapper tleft fleft&quot; href=&quot;/2019/index.php/th/ftunews-3/252-marathon2019&quot; style=&quot;margin:6px 14px 0 0;&quot; target=&quot;_self&quot;&gt;&lt;img alt=&quot;&quot; class=&quot;nspImage&quot; src=&quot;http://www.ftu.ac.th/2019/modules/mod_news_pro_gk5/cache/FTUEvents.2019m12.running_maathon1nsp-156.jpg&quot; style=&quot;width:320px;height:240px;&quot;/&gt;&lt;/a&gt;
# &lt;a class=&quot;readon fleft&quot; href=&quot;/2019/index.php/th/ftunews-3/252-marathon2019&quot; target=&quot;_self&quot;&gt;Read more&lt;/a&gt;
# ...

# %%
import numpy as np

# %%
np.array([print_hyperlinks])
# Out:
# array([&lt;function print_hyperlinks at 0x0000022041401828&gt;], dtype=object)
